# %%
import pandas as pd
import numpy as np
import statistics as st

# %%
df = pd.read_csv("C:\\Users\\paart\\Downloads\\movies_initial\\movies_initial.csv")

# %%
df
# Out:
#         imdbID                                   title  year     rating  \
# 0            1                              Carmencita  1894  NOT RATED
# 1            5                        Blacksmith Scene  1893    UNRATED
# 2            3                          Pauvre Pierrot  1892        NaN
# 3            8  Edison Kinetoscopic Record of a Sneeze  1894        NaN
# 4           10   Employees Leaving the Lumi�re Factory  1895        NaN
# ...        ...                                     ...   ...        ...
# 46009  5005684                       The New Classmate  2015        NaN
# 46010  5013056      Untitled Christopher Nolan Project  2017        NaN
# 46011  5013980                  Die Turnschuh-Giganten  2016        NaN
# 46012  5016760                The Monster of Mangatiti  2015        NaN
# 46013  5023260                           The Last Word  2016        NaN
#
#       runtime                     genre    released              director  \
# 0       1 min        Documentary, Short         NaN  William K.L. Dickson
# 1       1 min                     Short  1893-05-09  William K.L. Dickson
# 2       4 min  Animation, Comedy, Short  1892-10-28         �mile Reynaud
# 3       1 min        Documentary, Short  1894-01-09  William K.L. Dickson
# 4       1 min        Documentary, Short  1895-03-22         Louis Lumi�re
# ...       ...                       ...         ...                   ...
# 46009     NaN             Drama, Family  2015-10-11   Ashwiny Iyer Tiwari
# 46010     NaN                    Sci-Fi  2017-07-21     Christopher Nolan
# 46011     NaN     Biography, Drama, War         NaN      Oliver Dommenget
# 46012     NaN                       NaN  2015-09-06                   NaN
# 46013     NaN                    Comedy         NaN       Mark Pellington
#
#                                                   writer  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 46009                                                NaN
# 46010  Christopher Nolan (screenplay), Christopher Nolan
# 46011                                 Christian Schnalke
# 46012                                         John Banas
# 46013                                                NaN
#
#                                                     cast  ...  imdbRating  \
# 0                                             Carmencita  ...         5.9
# 1                               Charles Kayser, John Ott  ...         6.2
# 2                                                    NaN  ...         6.7
# 3                                               Fred Ott  ...         5.9
# 4                                                    NaN  ...         6.9
# ...                                                  ...  ...         ...
# 46009       Swara Bhaskar, Ratna Pathak, Pankaj Tripathy  ...         NaN
# 46010                                                NaN  ...         NaN
# 46011  Ken Duken, Florian Bartholom�i, Torben Liebrec...  ...         NaN
# 46012  Greta Gregory, Mark Mitchinson, Flynn Allan, H...  ...         NaN
# 46013                                    Amanda Seyfried  ...         NaN
#
#        imdbVotes                                             poster  \
# 0         1032.0  https://m.media-amazon.com/images/M/MV5BMjAzND...
# 1         1189.0                                                NaN
# 2          566.0                                                NaN
# 3          988.0                                                NaN
# 4         3469.0                                                NaN
# ...          ...                                                ...
# 46009        NaN                                                NaN
# 46010        NaN                                                NaN
# 46011        NaN                                                NaN
# 46012        NaN                                                NaN
# 46013        NaN                                                NaN
#
#                                                     plot  \
# 0      Performing on what looks like a small wooden s...
# 1      Three men hammer on an anvil and pass a bottle...
# 2      One night, Arlequin come to see his lover Colo...
# 3      A man (Thomas Edison's assistant) takes a pinc...
# 4      A man opens the big gates to the Lumi�re facto...
# ...                                                  ...
# 46009                                                NaN
# 46010                    Plot is being kept under wraps.
# 46011                                                NaN
# 46012  Heather Walsh tells her story of the time she ...
# 46013                                                NaN
#
#                                                 fullplot language  \
# 0      Performing on what looks like a small wooden s...      NaN
# 1      A stationary camera looks at a large anvil wit...      NaN
# 2      One night, Arlequin come to see his lover Colo...      NaN
# 3      A man (Edison's assistant) takes a pinch of sn...      NaN
# 4      A man opens the big gates to the Lumi�re facto...      NaN
# ...                                                  ...      ...
# 46009                                                NaN    Hindi
# 46010                    Plot is being kept under wraps.  English
# 46011                                                NaN   German
# 46012  Heather Walsh tells her story of the time she ...  English
# 46013                                                NaN  English
#
#            country  awards                    lastupdated   type
# 0              USA     NaN  2015-08-26 00:03:45.040000000  movie
# 1              USA  1 win.  2015-08-26 00:03:50.133000000  movie
# 2           France     NaN  2015-08-12 00:06:02.720000000  movie
# 3              USA     NaN  2015-08-10 00:21:07.127000000  movie
# 4           France     NaN  2015-08-26 00:03:56.603000000  movie
# ...            ...     ...                            ...    ...
# 46009        India     NaN  2015-09-10 22:28:58.883000000  movie
# 46010      USA, UK     NaN  2015-09-11 17:15:04.527000000  movie
# 46011      Germany     NaN  2015-09-12 23:13:48.997000000  movie
# 46012  New Zealand     NaN  2015-09-12 03:47:27.780000000  movie
# 46013          USA     NaN  2015-09-15 18:27:50.240000000  movie
#
# [46014 rows x 21 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46014 entries, 0 to 46013
# Data columns (total 21 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   imdbID       46014 non-null  int64
#  1   title        46014 non-null  object
#  2   year         46014 non-null  object
#  3   rating       24629 non-null  object
#  4   runtime      43377 non-null  object
#  5   genre        45615 non-null  object
#  6   released     43002 non-null  object
#  7   director     45409 non-null  object
#  8   writer       42942 non-null  object
#  9   cast         44928 non-null  object
#  10  metacritic   9401 non-null   float64
#  11  imdbRating   44300 non-null  float64
#  12  imdbVotes    44299 non-null  float64
#  13  poster       35798 non-null  object
#  14  plot         42161 non-null  object
#  15  fullplot     41421 non-null  object
#  16  language     44899 non-null  object
#  17  country      45830 non-null  object
#  18  awards       23542 non-null  object
#  19  lastupdated  46014 non-null  object
#  20  type         45976 non-null  object
# dtypes: float64(3), int64(1), object(17)
# memory usage: 7.4+ MB

# %%
#mean calculation
df.mean()
# Out:
# C:\Users\paart\AppData\Local\Temp\ipykernel_11404\2417271936.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.mean()
# imdbID        855206.215456
# metacritic        56.896288
# imdbRating         6.381454
# imdbVotes      11800.552134
# dtype: float64

# %%
df.mean(axis = 1)[0:5]
# Out:
# C:\Users\paart\AppData\Local\Temp\ipykernel_11404\369270116.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.mean(axis = 1)[0:5]
# 0     346.300000
# 1     400.066667
# 2     191.900000
# 3     333.966667
# 4    1161.966667
# dtype: float64

# %%
#median
df.median()
# Out:
# C:\Users\paart\AppData\Local\Temp\ipykernel_11404\1739800283.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.median()
# imdbID        252487.5
# metacritic        58.0
# imdbRating         6.6
# imdbVotes        999.0
# dtype: float64

# %%
df.median(axis = 1)[0:5]
# Out:
# C:\Users\paart\AppData\Local\Temp\ipykernel_11404\1941941222.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.median(axis = 1)[0:5]
# 0     5.9
# 1     6.2
# 2     6.7
# 3     8.0
# 4    10.0
# dtype: float64

# %%
df.mode()
# Out:
#       imdbID   title  year rating runtime  genre    released   director  \
# 0    67919.0  Hamlet  2015      R  90 min  Drama  2015-09-01  John Ford
# 1    69035.0     NaN   NaN    NaN     NaN    NaN         NaN        NaN
# 2   169302.0     NaN   NaN    NaN     NaN    NaN         NaN        NaN
# 3  1826550.0     NaN   NaN    NaN     NaN    NaN         NaN        NaN
# 4        NaN     NaN   NaN    NaN     NaN    NaN         NaN        NaN
#
#         writer            cast  ...  imdbRating  imdbVotes  \
# 0  Woody Allen  Georges M�li�s  ...         7.2       76.0
# 1          NaN             NaN  ...         NaN      109.0
# 2          NaN             NaN  ...         NaN        NaN
# 3          NaN             NaN  ...         NaN        NaN
# 4          NaN             NaN  ...         NaN        NaN
#
#                                               poster  \
# 0  https://m.media-amazon.com/images/M/MV5BMTcwMz...
# 1  https://m.media-amazon.com/images/M/MV5BMTk1ND...
# 2  https://m.media-amazon.com/images/M/MV5BMTk3Nj...
# 3  https://m.media-amazon.com/images/M/MV5BMjAwMT...
# 4  https://m.media-amazon.com/images/M/MV5BOTU5MT...
#
#                                 plot                           fullplot  \
# 0  The plot is unknown at this time.                   Plot is unknown.
# 1                                NaN  The plot is unknown at this time.
# 2                                NaN               The plot is unknown.
# 3                                NaN                                NaN
# 4                                NaN                                NaN
#
#   language country         awards                    lastupdated   type
# 0  English     USA  1 nomination.  2015-08-16 00:24:45.463000000  movie
# 1      NaN     NaN            NaN  2015-08-29 00:20:20.843000000    NaN
# 2      NaN     NaN            NaN                            NaN    NaN
# 3      NaN     NaN            NaN                            NaN    NaN
# 4      NaN     NaN            NaN                            NaN    NaN
#
# [5 rows x 21 columns]

# %%
#standard derivation
df.std()
# Out:
# C:\Users\paart\AppData\Local\Temp\ipykernel_11404\454836062.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.std()
# imdbID        1.141979e+06
# metacritic    1.771537e+01
# imdbRating    1.183113e+00
# imdbVotes     4.934499e+04
# dtype: float64

# %%
df.groupby(['year']).mean()
# Out:
#              imdbID  metacritic  imdbRating  imdbVotes
# year
# 1874   3.155794e+06         NaN       6.600     167.00
# 1880   2.221420e+06         NaN       7.300     326.00
# 1887   2.075247e+06         NaN       5.100     347.00
# 1888   1.050838e+06         NaN       6.450     984.50
# 1890   5.990105e+05         NaN       5.325     395.25
# ...             ...         ...         ...        ...
# 2016   3.817759e+06         NaN         NaN        NaN
# 2016�  3.816466e+06         NaN         NaN        NaN
# 2017   3.112227e+06         NaN         NaN        NaN
# 2018   4.680182e+06         NaN         NaN        NaN
# 2019   4.877122e+06         NaN         NaN        NaN
#
# [170 rows x 4 columns]

# %%
df.dropna()
# Out:
#         imdbID                         title  year     rating  runtime  \
# 432      17136                    Metropolis  1927  NOT RATED  153 min
# 1458     27977                  Modern Times  1936          G   87 min
# 1624     29453                  P�p� le Moko  1937  NOT RATED   94 min
# 1675     29843  The Adventures of Robin Hood  1938         PG  102 min
# 1929     32138              The Wizard of Oz  1939     PASSED  102 min
# ...        ...                           ...   ...        ...      ...
# 44708  4009460              Saving Christmas  2014         PG   80 min
# 44872  4104022          People Places Things  2015          R   85 min
# 44947  4145304                    Unexpected  2015          R   90 min
# 45015  4185572            The Hunting Ground  2015      PG-13  103 min
# 45092  4229236       Cobain: Montage of Heck  2015      TV-MA  145 min
#
#                                genre    released  \
# 432                    Drama, Sci-Fi  1927-03-13
# 1458                   Comedy, Drama  1936-02-25
# 1624           Crime, Drama, Romance  1941-03-03
# 1675      Action, Adventure, Romance  1938-05-14
# 1929      Adventure, Family, Fantasy  1939-08-25
# ...                              ...         ...
# 44708                 Comedy, Family  2014-11-14
# 44872                         Comedy  2015-08-14
# 44947                  Comedy, Drama  2015-07-24
# 45015                    Documentary  2015-01-23
# 45092  Documentary, Biography, Music  2015-05-04
#
#                                                 director  \
# 432                                           Fritz Lang
# 1458                                     Charles Chaplin
# 1624                                     Julien Duvivier
# 1675                    Michael Curtiz, William Keighley
# 1929   Victor Fleming, George Cukor, Mervyn LeRoy, No...
# ...                                                  ...
# 44708                                       Darren Doane
# 44872                                   James C. Strouse
# 44947                                      Kris Swanberg
# 45015                                         Kirby Dick
# 45092                                       Brett Morgen
#
#                                                   writer  \
# 432    Thea von Harbou (screenplay), Thea von Harbou ...
# 1458                                     Charles Chaplin
# 1624   Henri La Barthe (novel), Henri La Barthe (scen...
# 1675   Norman Reilly Raine (original screenplay: base...
# 1929   Noel Langley (screenplay), Florence Ryerson (s...
# ...                                                  ...
# 44708                       Darren Doane, Cheston Hervey
# 44872                                   James C. Strouse
# 44947                       Megan Mercier, Kris Swanberg
# 45015                                         Kirby Dick
# 45092                                       Brett Morgen
#
#                                                     cast  ...  imdbRating  \
# 432    Alfred Abel, Gustav Fr�hlich, Rudolf Klein-Rog...  ...         8.3
# 1458   Charles Chaplin, Paulette Goddard, Henry Bergm...  ...         8.6
# 1624   Jean Gabin, Gabriel Gabrio, Saturnin Fabre, Fe...  ...         7.8
# 1675   Errol Flynn, Olivia de Havilland, Basil Rathbo...  ...         8.0
# 1929   Judy Garland, Frank Morgan, Ray Bolger, Bert Lahr  ...         8.1
# ...                                                  ...  ...         ...
# 44708  Kirk Cameron, Darren Doane, Bridgette Cameron,...  ...         1.6
# 44872  Jemaine Clement, Regina Hall, Jessica Williams...  ...         7.0
# 44947  Cobie Smulders, Anders Holm, Gail Bean, Elizab...  ...         5.7
# 45015    Kirby Dick, Amy Ziering, Amy Herdy, Annie Clark  ...         6.4
# 45092  Aaron Burckhard, Chad Channing, Don Cobain, Je...  ...         7.7
#
#        imdbVotes                                             poster  \
# 432      99845.0  https://m.media-amazon.com/images/M/MV5BNDAzNT...
# 1458    123603.0  https://m.media-amazon.com/images/M/MV5BMjAyMT...
# 1624      4398.0  https://m.media-amazon.com/images/M/MV5BMTY5NT...
# 1675     36789.0  https://m.media-amazon.com/images/M/MV5BMTUxMz...
# 1929    262132.0  https://m.media-amazon.com/images/M/MV5BMTU0MT...
# ...          ...                                                ...
# 44708     9744.0  https://m.media-amazon.com/images/M/MV5BMTc3MT...
# 44872      628.0  https://m.media-amazon.com/images/M/MV5BMTg2Nj...
# 44947      661.0  https://m.media-amazon.com/images/M/MV5BMjM5NT...
# 45015      324.0  https://m.media-amazon.com/images/M/MV5BNjc4Mj...
# 45092    13973.0  https://m.media-amazon.com/images/M/MV5BMjIyOT...
#
#                                                     plot  \
# 432    In a futuristic city sharply divided between t...
# 1458   The Tramp struggles to live in modern industri...
# 1624   P�p� le Moko is a gangster from Paris that hid...
# 1675   When Prince John and the Norman Lords begin op...
# 1929   Dorothy Gale is swept away to a magical land i...
# ...                                                  ...
# 44708  Kirk is enjoying the annual Christmas party ex...
# 44872  Will Henry is a newly single graphic novelist ...
# 44947  An inner-city high school teacher discovers sh...
# 45015  An expos� of rape crimes on U.S. college campu...
# 45092  An authorized documentary on the late musician...
#
#                                                 fullplot        language  \
# 432    Sometime in the future, the city of Metropolis...          German
# 1458   Chaplins last 'silent' film, filled with sound...         English
# 1624   P�p� le Moko is a gangster from Paris that hid...  French, Arabic
# 1675   Sir Robin of Locksley, defender of downtrodden...         English
# 1929   In this charming film based on the popular L. ...         English
# ...                                                  ...             ...
# 44708  Kirk is enjoying the annual Christmas party ex...         English
# 44872  PEOPLE PLACES THINGS tells the story of Will H...         English
# 44947  An inner-city high school teacher discovers sh...         English
# 45015  From the makers of The Invisible War (2012) co...         English
# 45092  An authorized documentary on the late musician...         English
#
#        country                                           awards  \
# 432    Germany                          3 wins & 4 nominations.
# 1458       USA                           3 wins & 1 nomination.
# 1624    France                                          2 wins.
# 1675       USA    Won 3 Oscars. Another 2 wins & 2 nominations.
# 1929       USA   Won 2 Oscars. Another 7 wins & 13 nominations.
# ...        ...                                              ...
# 44708      USA                          4 wins & 2 nominations.
# 44872      USA                                    1 nomination.
# 44947      USA                                    1 nomination.
# 45015      USA                                    1 nomination.
# 45092      USA  Nominated for 6 Primetime Emmys. Another 1 win.
#
#                          lastupdated   type
# 432    2015-09-04 00:09:30.553000000  movie
# 1458   2015-09-04 00:06:38.867000000  movie
# 1624   2015-09-10 17:45:12.290000000  movie
# 1675   2015-08-14 00:11:51.833000000  movie
# 1929   2015-09-01 00:29:05.490000000  movie
# ...                              ...    ...
# 44708  2015-08-16 00:12:45.527000000  movie
# 44872  2015-08-31 00:01:35.920000000  movie
# 44947  2015-09-06 00:20:02.930000000  movie
# 45015  2015-08-29 00:23:33.937000000  movie
# 45092  2015-09-17 04:40:35.987000000  movie
#
# [6148 rows x 21 columns]
