# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
df = pd.read_csv('C:\\Users\\paart\\Downloads\\iris-dataset\\iris.csv')

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %%
sns.pairplot(data=df,hue='variety')

# %%
row = 2
col = 2
s = 0
fig, ax = plt.subplots(nrows=row, ncols=col, figsize=(15,8))
for i in range(row):
    for j in range(col):
        sns.histplot(x=df.columns[s],data=df,kde=True, ax=ax[i][j])
        s +=1

# %%
fig, ax = plt.subplots(figsize=(15,8))
sns.boxplot(data=df,ax=ax)
# Out:
# <AxesSubplot:>

# %%
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
q1 = df.sepal_width.quantile(0.25)
q3 = df.sepal_width.quantile(0.75)
q1,q3
# Out:
# (2.8, 3.3)

# %%
iqr = q3-q1
iqr
# Out:
# 0.5

# %%
l_limit = q1-1.5*iqr
u_limit = q3+1.5*iqr
l_limit,u_limit
# Out:
# (2.05, 4.05)

# %%
df[(df['sepal_width']<l_limit) | (df['sepal_width']>u_limit)]
# Out:
#     sepal_length  sepal_width  petal_length  petal_width     variety
# 15           5.7          4.4           1.5          0.4      Setosa
# 32           5.2          4.1           1.5          0.1      Setosa
# 33           5.5          4.2           1.4          0.2      Setosa
# 60           5.0          2.0           3.5          1.0  Versicolor

# %%
df =df[(df['sepal_width']>l_limit) & (df['sepal_width']<u_limit)]

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [146 rows x 5 columns]

# %%
fig, ax = plt.subplots(figsize=(15,8))
sns.boxplot(data=df,ax=ax)
# Out:
# <AxesSubplot:>
